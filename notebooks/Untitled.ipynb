# %%
# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
from fastai_bayesian import *
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-2-9e5d370ceacd> in <module>
# ----> 1 from fastai_bayesian import *
#
# ModuleNotFoundError: No module named 'fastai_bayesian'
